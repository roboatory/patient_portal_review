# %%
import bisect
from bs4 import BeautifulSoup
from datetime import datetime
import math
import pandas as pd
import re
from selenium import webdriver
import time

# %%
SCROLL_PAUSE_TIME = 0.5

# %%
def tokenize_responses(disease, posts_dataframe):
    sentence_dataframe = pd.read_csv("gold_standard/sentences/" + disease + ".tsv", delimiter = "\t")
    
    for sentence_number, sentence in sentence_dataframe.iterrows():
        post = posts_dataframe[posts_dataframe["post_id"] == sentence["post_id"]]["post"].item()
        
        if isinstance(post, float) and math.isnan(post):
            break
        else:
#             print("Start index: {}, end index: {}".format(sentence["start_index"], sentence["end_index"]))
#             print("Mined sentence (number: {}): {}\n".format(sentence_number, post[sentence["start_index"] - 1 :
#                                                                                    sentence["end_index"] - 1].strip()))
            sentence_dataframe.loc[sentence_number, "sentence"] = post[sentence["start_index"] - 1 :
                                                                       sentence["end_index"] - 1].strip()
    
    print(sentence_dataframe.head(50))

# %%
def add_posts(conversation_posts, usernames, posts_dataframe, conversation_id):
    start_row = posts_dataframe[posts_dataframe["conversation_id"] == conversation_id].index[0]
    end_row = posts_dataframe[posts_dataframe["conversation_id"] == conversation_id].index[-1]
    
    for post_number in range(start_row, end_row + 1):
        print("Expected author of post {} is {}".format(post_number, posts_dataframe.loc[post_number, "author"]))
        print("Extracted author of post {} is {}".format(post_number, usernames[post_number - start_row]))
        print("Match? {}\n".format(posts_dataframe.loc[post_number, "author"] ==
                                   usernames[post_number - start_row]))
        
        if (usernames[post_number - start_row] == posts_dataframe.loc[post_number, "author"]):
            posts_dataframe.loc[post_number, "post"] = conversation_posts[post_number - start_row]

# %%
def scrape_url(conversation_url):
    print("Conversation URL: {}\n".format(conversation_url))
    
    # setup selenium web driver to crawl page with infinite scrolling
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument("--incognito")
    chrome_options.add_argument("headless")

    driver = webdriver.Chrome(options = chrome_options)
    driver.get(conversation_url + "?sort_by=oldest")
    
    last_height = driver.execute_script("return document.body.scrollHeight;")

    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
        new_height = driver.execute_script("return document.body.scrollHeight;")
        if new_height == last_height: break
        last_height = new_height

    soup = BeautifulSoup(driver.page_source)
    
    # responses encapsulated in outer div with class post_show_{ID}
    post_list = soup.find("div", {"id" : "post_show_" + conversation_url.split("/")[-1]})
    
    # original poster and contents encapsulated in divs with class "subj_info" and "subject_msg" 
    original_post = soup.find("div", {"id" : "subject_msg"}).text
    original_user_data = (soup.find("div", {"class" : "subj_info"})
                              .find("div", {"class" : "username"}))
    original_username = original_user_data.a.text
    
    try:
        original_date = datetime.strptime(original_user_data.time.text, "%b %d, %Y")
    except ValueError:
        print("Encountered post without specified year; assuming post was authored in current year\n")
        original_date = datetime.strptime(original_user_data.time.text + 
                                          ", {}".format(datetime.now().year), "%b %d, %Y")
    
    # for posts with a "best" answer, find that card and extract its contents -- 
    # encapsulated in outer div with class containing "best_answer_card"
    best_answer_card = soup.find("div", {"class" : re.compile(r"best_answer_card")})
    if best_answer_card:
        best_post = best_answer_card.find("div", {"class" : "comment_body"}).text
        best_answer_user_data = (best_answer_card.find("div", {"class" : "resp_info"})
                                                 .find("div", {"class" : "username"}))
        best_answer_username = best_answer_user_data.a.text
        
        try:
            best_answer_date = datetime.strptime(best_answer_user_data.time.text, "%b %d, %Y")
        except ValueError:
            print("Encountered post without specified year; assuming post was authored in current year\n")
            best_answer_date = datetime.strptime(best_answer_user_data.time.text + 
                                                 ", {}".format(datetime.now().year), "%b %d, %Y")
    
    # extract replies
    posts = [original_post] if not best_answer_card else [original_post, best_post]
    responses = post_list.find_all("div", {"class" : "resp_body"})
    for response in responses:
        posts.append(response.text)
    
    # extract user metadata (username & date)
    usernames = [original_username] if not best_answer_card else [original_username, best_answer_username]
    timestamps = [original_date] if not best_answer_card else [original_date, best_answer_date]
    responders = post_list.find_all("div", {"class" : "resp_info"})
    for responder in responders:
        responder = responder.find("div", {"class" : "username"})
        usernames.append(responder.a.text)
        
        try:
            timestamps.append(datetime.strptime(responder.time.text, "%b %d, %Y"))
        except ValueError:
            print("Encountered post without specified year; assuming post was authored in current year\n")
            timestamps.append(datetime.strptime(responder.time.text + 
                                                ", {}".format(datetime.now().year), "%b %d, %Y"))
    
    # duplicate best answer response and insert in chronological order
    if best_answer_card:
        insertion_point = bisect.bisect(timestamps, best_answer_date, lo = 2)
        usernames.insert(insertion_point, best_answer_username)
        posts.insert(insertion_point, best_post)
        
    assert(len(usernames) == len(posts))

    # clean web scraped text
    for index in range(len(posts)):
        posts[index] = posts[index].replace(u"\xa0", " ").strip()
        
    return posts, usernames

# %%
def scrape_conversation_posts(disease):
    conversations = pd.read_csv("gold_standard/conversations/" + disease + ".tsv", delimiter = "\t")
    posts_dataframe = pd.read_csv("gold_standard/posts/" + disease + ".tsv", delimiter = "\t")
    expected_posts_per_conversation = posts_dataframe["conversation_id"].value_counts()
    
    for index, row in conversations.iterrows():
        conversation_posts, usernames = scrape_url(row["url"])
        
#         print("Collected posts: {}\n".format(conversation_posts))
        print("Number of extracted conversation posts / usernames: {}".format(len(conversation_posts)))
        print("Expected number of posts to be analyzed: {}\n".format(
            expected_posts_per_conversation[row["conversation_id"]]))
        assert(len(conversation_posts) >= expected_posts_per_conversation[row["conversation_id"]])
        
        add_posts(conversation_posts, usernames, posts_dataframe, row["conversation_id"])
        
    return posts_dataframe

# %%
def driver():
    diseases = pd.read_csv("gold_standard/diseases/diseases.tsv", delimiter = "\t")
    
    for disease in diseases["disease_id"]:
        print("Disease ID: {}\n".format(disease))
        posts_dataframe = scrape_conversation_posts(disease)
        # tokenize_responses(disease, posts_dataframe)

# %%
driver()
# Out:
# Disease ID: HIF2016_DIS00
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Does-anyone-have-an-allergy-to-coffee/show/1550820
#
# Number of extracted conversation posts / usernames: 31
# Expected number of posts to be analyzed: 31
#
# Expected author of post 0 is seattlemom2plus
# Extracted author of post 0 is seattlemom2plus
# Match? True
#
# Expected author of post 1 is ChitChatNine
# Extracted author of post 1 is ChitChatNine
# Match? True
#
# Expected author of post 2 is FurballsMom
# Extracted author of post 2 is FurballsMom
# Match? True
#
# Expected author of post 3 is seattlemom2plus
# Extracted author of post 3 is seattlemom2plus
# Match? True
#
# Expected author of post 4 is FurballsMom
# Extracted author of post 4 is FurballsMom
# Match? True
#
# Expected author of post 5 is seattlemom2plus
# Extracted author of post 5 is seattlemom2plus
# Match? True
#
# Expected author of post 6 is FurballsMom
# Extracted author of post 6 is FurballsMom
# Match? True
#
# Expected author of post 7 is seattlemom2plus
# Extracted author of post 7 is seattlemom2plus
# Match? True
#
# Expected author of post 8 is FergalEmmanuel
# Extracted author of post 8 is FergalEmmanuel
# Match? True
#
# Expected author of post 9 is FurballsMom
# Extracted author of post 9 is FurballsMom
# Match? True
#
# Expected author of post 10 is seattlemom2plus
# Extracted author of post 10 is seattlemom2plus
# Match? True
#
# Expected author of post 11 is betbri
# Extracted author of post 11 is betbri
# Match? True
#
# Expected author of post 12 is betbri
# Extracted author of post 12 is betbri
# Match? True
#
# Expected author of post 13 is FurballsMom
# Extracted author of post 13 is FurballsMom
# Match? True
#
# Expected author of post 14 is seattlemom2plus
# Extracted author of post 14 is seattlemom2plus
# Match? True
#
# Expected author of post 15 is betbri
# Extracted author of post 15 is betbri
# Match? True
#
# Expected author of post 16 is seattlemom2plus
# Extracted author of post 16 is seattlemom2plus
# Match? True
#
# Expected author of post 17 is FurballsMom
# Extracted author of post 17 is FurballsMom
# Match? True
#
# Expected author of post 18 is betbri
# Extracted author of post 18 is betbri
# Match? True
#
# Expected author of post 19 is FurballsMom
# Extracted author of post 19 is FurballsMom
# Match? True
#
# Expected author of post 20 is seattlemom2plus
# Extracted author of post 20 is seattlemom2plus
# Match? True
#
# Expected author of post 21 is angieuncw
# Extracted author of post 21 is angieuncw
# Match? True
#
# Expected author of post 22 is janeparker2013
# Extracted author of post 22 is janeparker2013
# Match? True
#
# Expected author of post 23 is Eimhir
# Extracted author of post 23 is Eimhir
# Match? True
#
# Expected author of post 24 is Nora147
# Extracted author of post 24 is Nora147
# Match? True
#
# Expected author of post 25 is ChitChatNine
# Extracted author of post 25 is ChitChatNine
# Match? True
#
# Expected author of post 26 is Pantherone
# Extracted author of post 26 is Pantherone
# Match? True
#
# Expected author of post 27 is Krissandra
# Extracted author of post 27 is Krissandra
# Match? True
#
# Expected author of post 28 is coffeesneezes
# Extracted author of post 28 is coffeesneezes
# Match? True
#
# Expected author of post 29 is pixelpixie777
# Extracted author of post 29 is pixelpixie777
# Match? True
#
# Expected author of post 30 is Success2018
# Extracted author of post 30 is Success2018
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Tyramine-intolerance---hidden-allergy/show/1235498
#
# Encountered post without specified year; assuming post was authored in current year
#
# Number of extracted conversation posts / usernames: 23
# Expected number of posts to be analyzed: 14
#
# Expected author of post 31 is soflasof
# Extracted author of post 31 is soflasof
# Match? True
#
# Expected author of post 32 is enzymelover
# Extracted author of post 32 is enzymelover
# Match? True
#
# Expected author of post 33 is ChitChatNine
# Extracted author of post 33 is ChitChatNine
# Match? True
#
# Expected author of post 34 is Philippe58
# Extracted author of post 34 is Philippe58
# Match? True
#
# Expected author of post 35 is MBA931
# Extracted author of post 35 is MBA931
# Match? True
#
# Expected author of post 36 is Zascha
# Extracted author of post 36 is Zascha
# Match? True
#
# Expected author of post 37 is FurballsMom
# Extracted author of post 37 is FurballsMom
# Match? True
#
# Expected author of post 38 is masnow
# Extracted author of post 38 is masnow
# Match? True
#
# Expected author of post 39 is FurballsMom
# Extracted author of post 39 is FurballsMom
# Match? True
#
# Expected author of post 40 is Deuce04
# Extracted author of post 40 is Deuce04
# Match? True
#
# Expected author of post 41 is Patequack
# Extracted author of post 41 is Patequack
# Match? True
#
# Expected author of post 42 is shoh
# Extracted author of post 42 is shoh
# Match? True
#
# Expected author of post 43 is Lasserman
# Extracted author of post 43 is Lasserman
# Match? True
#
# Expected author of post 44 is Deb0705
# Extracted author of post 44 is Deb0705
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Shellfish-allergy/show/2491698
#
# Number of extracted conversation posts / usernames: 11
# Expected number of posts to be analyzed: 11
#
# Expected author of post 45 is Smiley2000
# Extracted author of post 45 is Smiley2000
# Match? True
#
# Expected author of post 46 is SassyLassie
# Extracted author of post 46 is SassyLassie
# Match? True
#
# Expected author of post 47 is masterblogger
# Extracted author of post 47 is masterblogger
# Match? True
#
# Expected author of post 48 is Smiley2000
# Extracted author of post 48 is Smiley2000
# Match? True
#
# Expected author of post 49 is Smiley2000
# Extracted author of post 49 is Smiley2000
# Match? True
#
# Expected author of post 50 is Smiley2000
# Extracted author of post 50 is Smiley2000
# Match? True
#
# Expected author of post 51 is SassyLassie
# Extracted author of post 51 is SassyLassie
# Match? True
#
# Expected author of post 52 is Smiley2000
# Extracted author of post 52 is Smiley2000
# Match? True
#
# Expected author of post 53 is Smiley2000
# Extracted author of post 53 is Smiley2000
# Match? True
#
# Expected author of post 54 is djtsurfer
# Extracted author of post 54 is djtsurfer
# Match? True
#
# Expected author of post 55 is masterblogger
# Extracted author of post 55 is masterblogger
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Neee-help/show/2157463
#
# Number of extracted conversation posts / usernames: 13
# Expected number of posts to be analyzed: 13
#
# Expected author of post 56 is lpjay
# Extracted author of post 56 is lpjay
# Match? True
#
# Expected author of post 57 is evewisewoman
# Extracted author of post 57 is evewisewoman
# Match? True
#
# Expected author of post 58 is lpjay
# Extracted author of post 58 is lpjay
# Match? True
#
# Expected author of post 59 is evewisewoman
# Extracted author of post 59 is evewisewoman
# Match? True
#
# Expected author of post 60 is lpjay
# Extracted author of post 60 is lpjay
# Match? True
#
# Expected author of post 61 is evewisewoman
# Extracted author of post 61 is evewisewoman
# Match? True
#
# Expected author of post 62 is evewisewoman
# Extracted author of post 62 is evewisewoman
# Match? True
#
# Expected author of post 63 is evewisewoman
# Extracted author of post 63 is evewisewoman
# Match? True
#
# Expected author of post 64 is lpjay
# Extracted author of post 64 is lpjay
# Match? True
#
# Expected author of post 65 is dpinker1
# Extracted author of post 65 is dpinker1
# Match? True
#
# Expected author of post 66 is evewisewoman
# Extracted author of post 66 is evewisewoman
# Match? True
#
# Expected author of post 67 is dpinker1
# Extracted author of post 67 is dpinker1
# Match? True
#
# Expected author of post 68 is evewisewoman
# Extracted author of post 68 is evewisewoman
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Is-it-possible-to-be-allergic-to-meat/show/1503543
#
# Number of extracted conversation posts / usernames: 17
# Expected number of posts to be analyzed: 14
#
# Expected author of post 69 is PeaceMouse
# Extracted author of post 69 is PeaceMouse
# Match? True
#
# Expected author of post 70 is PeaceMouse
# Extracted author of post 70 is PeaceMouse
# Match? True
#
# Expected author of post 71 is seattlemom2plus
# Extracted author of post 71 is seattlemom2plus
# Match? True
#
# Expected author of post 72 is ChitChatNine
# Extracted author of post 72 is ChitChatNine
# Match? True
#
# Expected author of post 73 is PeaceMouse
# Extracted author of post 73 is PeaceMouse
# Match? True
#
# Expected author of post 74 is ChitChatNine
# Extracted author of post 74 is ChitChatNine
# Match? True
#
# Expected author of post 75 is seattlemom2plus
# Extracted author of post 75 is seattlemom2plus
# Match? True
#
# Expected author of post 76 is ChitChatNine
# Extracted author of post 76 is ChitChatNine
# Match? True
#
# Expected author of post 77 is SassyLassie
# Extracted author of post 77 is SassyLassie
# Match? True
#
# Expected author of post 78 is FurballsMom
# Extracted author of post 78 is FurballsMom
# Match? True
#
# Expected author of post 79 is ChitChatNine
# Extracted author of post 79 is ChitChatNine
# Match? True
#
# Expected author of post 80 is ChitChatNine
# Extracted author of post 80 is ChitChatNine
# Match? True
#
# Expected author of post 81 is FurballsMom
# Extracted author of post 81 is FurballsMom
# Match? True
#
# Expected author of post 82 is TStull65
# Extracted author of post 82 is TStull65
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Tremors-when-touching-certain-foods/show/1537785
# Number of extracted conversation posts / usernames: 13
# Expected number of posts to be analyzed: 13
#
# Expected author of post 83 is Jayhawk29
# Extracted author of post 83 is Jayhawk29
# Match? True
#
# Expected author of post 84 is Ashwin Bhandari, MBBS
# Extracted author of post 84 is Ashwin  Bhandari, MBBS
# Match? False
#
# Expected author of post 85 is Jayhawk29
# Extracted author of post 85 is Jayhawk29
# Match? True
#
# Expected author of post 86 is Paderla Anitha, DNB
# Extracted author of post 86 is Paderla  Anitha, DNB
# Match? False
#
# Expected author of post 87 is Jayhawk29
# Extracted author of post 87 is Jayhawk29
# Match? True
#
# Expected author of post 88 is seattlemom2plus
# Extracted author of post 88 is seattlemom2plus
# Match? True
#
# Expected author of post 89 is Jayhawk29
# Extracted author of post 89 is Jayhawk29
# Match? True
#
# Expected author of post 90 is ChitChatNine
# Extracted author of post 90 is ChitChatNine
# Match? True
#
# Expected author of post 91 is seattlemom2plus
# Extracted author of post 91 is seattlemom2plus
# Match? True
#
# Expected author of post 92 is Jayhawk29
# Extracted author of post 92 is Jayhawk29
# Match? True
#
# Expected author of post 93 is seattlemom2plus
# Extracted author of post 93 is seattlemom2plus
# Match? True
#
# Expected author of post 94 is wilsongarrett
# Extracted author of post 94 is wilsongarrett
# Match? True
#
# Expected author of post 95 is ChitChatNine
# Extracted author of post 95 is ChitChatNine
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Is-my-husband-allergic-to-wheat/show/1508708
#
# Number of extracted conversation posts / usernames: 12
# Expected number of posts to be analyzed: 12
#
# Expected author of post 96 is seattlemom2plus
# Extracted author of post 96 is seattlemom2plus
# Match? True
#
# Expected author of post 97 is skyi
# Extracted author of post 97 is skyi
# Match? True
#
# Expected author of post 98 is seattlemom2plus
# Extracted author of post 98 is seattlemom2plus
# Match? True
#
# Expected author of post 99 is SassyLassie
# Extracted author of post 99 is SassyLassie
# Match? True
#
# Expected author of post 100 is seattlemom2plus
# Extracted author of post 100 is seattlemom2plus
# Match? True
#
# Expected author of post 101 is ChitChatNine
# Extracted author of post 101 is ChitChatNine
# Match? True
#
# Expected author of post 102 is seattlemom2plus
# Extracted author of post 102 is seattlemom2plus
# Match? True
#
# Expected author of post 103 is kashwell
# Extracted author of post 103 is kashwell
# Match? True
#
# Expected author of post 104 is seattlemom2plus
# Extracted author of post 104 is seattlemom2plus
# Match? True
#
# Expected author of post 105 is ChitChatNine
# Extracted author of post 105 is ChitChatNine
# Match? True
#
# Expected author of post 106 is FurballsMom
# Extracted author of post 106 is FurballsMom
# Match? True
#
# Expected author of post 107 is seattlemom2plus
# Extracted author of post 107 is seattlemom2plus
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Swollen-Mouth/show/2241058
#
# Number of extracted conversation posts / usernames: 9
# Expected number of posts to be analyzed: 9
#
# Expected author of post 108 is Concerned_N_TX
# Extracted author of post 108 is Concerned_N_TX
# Match? True
#
# Expected author of post 109 is evewisewoman
# Extracted author of post 109 is evewisewoman
# Match? True
#
# Expected author of post 110 is Concerned_N_TX
# Extracted author of post 110 is Concerned_N_TX
# Match? True
#
# Expected author of post 111 is evewisewoman
# Extracted author of post 111 is evewisewoman
# Match? True
#
# Expected author of post 112 is Concerned_N_TX
# Extracted author of post 112 is Concerned_N_TX
# Match? True
#
# Expected author of post 113 is evewisewoman
# Extracted author of post 113 is evewisewoman
# Match? True
#
# Expected author of post 114 is maribanks
# Extracted author of post 114 is maribanks
# Match? True
#
# Expected author of post 115 is Concerned_N_TX
# Extracted author of post 115 is Concerned_N_TX
# Match? True
#
# Expected author of post 116 is masterblogger
# Extracted author of post 116 is masterblogger
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Latex-allergies-and-foods/show/746345
#
# Number of extracted conversation posts / usernames: 15
# Expected number of posts to be analyzed: 15
#
# Expected author of post 117 is peekawho
# Extracted author of post 117 is peekawho
# Match? True
#
# Expected author of post 118 is ChitChatNine
# Extracted author of post 118 is ChitChatNine
# Match? True
#
# Expected author of post 119 is peekawho
# Extracted author of post 119 is peekawho
# Match? True
#
# Expected author of post 120 is 1nana
# Extracted author of post 120 is 1nana
# Match? True
#
# Expected author of post 121 is ChitChatNine
# Extracted author of post 121 is ChitChatNine
# Match? True
#
# Expected author of post 122 is 1nana
# Extracted author of post 122 is 1nana
# Match? True
#
# Expected author of post 123 is ChitChatNine
# Extracted author of post 123 is ChitChatNine
# Match? True
#
# Expected author of post 124 is peekawho
# Extracted author of post 124 is peekawho
# Match? True
#
# Expected author of post 125 is p1p
# Extracted author of post 125 is p1p
# Match? True
#
# Expected author of post 126 is FurballsMom
# Extracted author of post 126 is FurballsMom
# Match? True
#
# Expected author of post 127 is FurballsMom
# Extracted author of post 127 is FurballsMom
# Match? True
#
# Expected author of post 128 is ChitChatNine
# Extracted author of post 128 is ChitChatNine
# Match? True
#
# Expected author of post 129 is LexiFaye
# Extracted author of post 129 is LexiFaye
# Match? True
#
# Expected author of post 130 is Trialanderror
# Extracted author of post 130 is Trialanderror
# Match? True
#
# Expected author of post 131 is ChitChatNine
# Extracted author of post 131 is ChitChatNine
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/36-and-just-had-my-first-reaction-to-shrimp/show/1542663
#
# Number of extracted conversation posts / usernames: 15
# Expected number of posts to be analyzed: 15
#
# Expected author of post 132 is seattlemom2plus
# Extracted author of post 132 is seattlemom2plus
# Match? True
#
# Expected author of post 133 is ChitChatNine
# Extracted author of post 133 is ChitChatNine
# Match? True
#
# Expected author of post 134 is ChitChatNine
# Extracted author of post 134 is ChitChatNine
# Match? True
#
# Expected author of post 135 is seattlemom2plus
# Extracted author of post 135 is seattlemom2plus
# Match? True
#
# Expected author of post 136 is ChitChatNine
# Extracted author of post 136 is ChitChatNine
# Match? True
#
# Expected author of post 137 is seattlemom2plus
# Extracted author of post 137 is seattlemom2plus
# Match? True
#
# Expected author of post 138 is seattlemom2plus
# Extracted author of post 138 is seattlemom2plus
# Match? True
#
# Expected author of post 139 is FurballsMom
# Extracted author of post 139 is FurballsMom
# Match? True
#
# Expected author of post 140 is ChitChatNine
# Extracted author of post 140 is ChitChatNine
# Match? True
#
# Expected author of post 141 is seattlemom2plus
# Extracted author of post 141 is seattlemom2plus
# Match? True
#
# Expected author of post 142 is Paderla Anitha, DNB
# Extracted author of post 142 is Paderla  Anitha, DNB
# Match? False
#
# Expected author of post 143 is seattlemom2plus
# Extracted author of post 143 is seattlemom2plus
# Match? True
#
# Expected author of post 144 is ChitChatNine
# Extracted author of post 144 is ChitChatNine
# Match? True
#
# Expected author of post 145 is ChitChatNine
# Extracted author of post 145 is ChitChatNine
# Match? True
#
# Expected author of post 146 is seattlemom2plus
# Extracted author of post 146 is seattlemom2plus
# Match? True
#
# Disease ID: HIF2016_DIS01
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/chrons-with-negative-colonoscopy/show/476110
#
# Number of extracted conversation posts / usernames: 33
# Expected number of posts to be analyzed: 31
#
# Expected author of post 0 is saradan
# Extracted author of post 0 is saradan
# Match? True
#
# Expected author of post 1 is elroque
# Extracted author of post 1 is elroque
# Match? True
#
# Expected author of post 2 is lizziecee
# Extracted author of post 2 is lizziecee
# Match? True
#
# Expected author of post 3 is April2
# Extracted author of post 3 is April2
# Match? True
#
# Expected author of post 4 is saradan
# Extracted author of post 4 is saradan
# Match? True
#
# Expected author of post 5 is georgie439
# Extracted author of post 5 is georgie439
# Match? True
#
# Expected author of post 6 is PrincessKatie
# Extracted author of post 6 is PrincessKatie
# Match? True
#
# Expected author of post 7 is spazzy24
# Extracted author of post 7 is spazzy24
# Match? True
#
# Expected author of post 8 is soldiersgirl336
# Extracted author of post 8 is soldiersgirl336
# Match? True
#
# Expected author of post 9 is Montey25
# Extracted author of post 9 is Montey25
# Match? True
#
# Expected author of post 10 is Kathy942
# Extracted author of post 10 is Kathy942
# Match? True
#
# Expected author of post 11 is ill13632
# Extracted author of post 11 is ill13632
# Match? True
#
# Expected author of post 12 is nkf738
# Extracted author of post 12 is nkf738
# Match? True
#
# Expected author of post 13 is diggs1973
# Extracted author of post 13 is diggs1973
# Match? True
#
# Expected author of post 14 is riot106
# Extracted author of post 14 is riot106
# Match? True
#
# Expected author of post 15 is Col73
# Extracted author of post 15 is Col73
# Match? True
#
# Expected author of post 16 is monkeyk
# Extracted author of post 16 is monkeyk
# Match? True
#
# Expected author of post 17 is CrohnieToo
# Extracted author of post 17 is CrohnieToo
# Match? True
#
# Expected author of post 18 is CrohnieToo
# Extracted author of post 18 is CrohnieToo
# Match? True
#
# Expected author of post 19 is club2420
# Extracted author of post 19 is club2420
# Match? True
#
# Expected author of post 20 is avenge
# Extracted author of post 20 is avenge
# Match? True
#
# Expected author of post 21 is EmSaCo
# Extracted author of post 21 is EmSaCo
# Match? True
#
# Expected author of post 22 is GDP1966
# Extracted author of post 22 is GDP1966
# Match? True
#
# Expected author of post 23 is TiredDesperate
# Extracted author of post 23 is TiredDesperate
# Match? True
#
# Expected author of post 24 is Sbgirl3836
# Extracted author of post 24 is Sbgirl3836
# Match? True
#
# Expected author of post 25 is stylish69
# Extracted author of post 25 is stylish69
# Match? True
#
# Expected author of post 26 is Ray8888
# Extracted author of post 26 is Ray8888
# Match? True
#
# Expected author of post 27 is Niklee327
# Extracted author of post 27 is Niklee327
# Match? True
#
# Expected author of post 28 is lfdmaster
# Extracted author of post 28 is lfdmaster
# Match? True
#
# Expected author of post 29 is cynthiawan
# Extracted author of post 29 is cynthiawan
# Match? True
#
# Expected author of post 30 is steph4528
# Extracted author of post 30 is steph4528
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Crohns-IBS-and-herpes-simplex-2---are-they-all-related/show/1486989
# Number of extracted conversation posts / usernames: 10
# Expected number of posts to be analyzed: 10
#
# Expected author of post 31 is Maza69
# Extracted author of post 31 is Maza69
# Match? True
#
# Expected author of post 32 is emg454
# Extracted author of post 32 is emg454
# Match? True
#
# Expected author of post 33 is emg454
# Extracted author of post 33 is emg454
# Match? True
#
# Expected author of post 34 is KimK1
# Extracted author of post 34 is KimK1
# Match? True
#
# Expected author of post 35 is meow07
# Extracted author of post 35 is meow07
# Match? True
#
# Expected author of post 36 is LOSTG1RL78
# Extracted author of post 36 is LOSTG1RL78
# Match? True
#
# Expected author of post 37 is Liveroom
# Extracted author of post 37 is Liveroom
# Match? True
#
# Expected author of post 38 is Liveroom
# Extracted author of post 38 is Liveroom
# Match? True
#
# Expected author of post 39 is Megadodger
# Extracted author of post 39 is Megadodger
# Match? True
#
# Expected author of post 40 is IBS_Coach
# Extracted author of post 40 is IBS_Coach
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Crohns-disease-and-back-pain/show/399517
#
# Number of extracted conversation posts / usernames: 37
# Expected number of posts to be analyzed: 37
#
# Expected author of post 41 is KentuckyBeMommaw
# Extracted author of post 41 is KentuckyBeMommaw
# Match? True
#
# Expected author of post 42 is KentuckyBeMommaw
# Extracted author of post 42 is KentuckyBeMommaw
# Match? True
#
# Expected author of post 43 is KJay57
# Extracted author of post 43 is KJay57
# Match? True
#
# Expected author of post 44 is dancepage
# Extracted author of post 44 is dancepage
# Match? True
#
# Expected author of post 45 is gingerpotter
# Extracted author of post 45 is gingerpotter
# Match? True
#
# Expected author of post 46 is gingerpotter
# Extracted author of post 46 is gingerpotter
# Match? True
#
# Expected author of post 47 is gingerpotter
# Extracted author of post 47 is gingerpotter
# Match? True
#
# Expected author of post 48 is Lalasoto
# Extracted author of post 48 is Lalasoto
# Match? True
#
# Expected author of post 49 is VCASILLAS
# Extracted author of post 49 is VCASILLAS
# Match? True
#
# Expected author of post 50 is jessnmy2girls
# Extracted author of post 50 is jessnmy2girls
# Match? True
#
# Expected author of post 51 is ladylori24
# Extracted author of post 51 is ladylori24
# Match? True
#
# Expected author of post 52 is maggiemae288
# Extracted author of post 52 is maggiemae288
# Match? True
#
# Expected author of post 53 is slonyara
# Extracted author of post 53 is slonyara
# Match? True
#
# Expected author of post 54 is TrudieC
# Extracted author of post 54 is TrudieC
# Match? True
#
# Expected author of post 55 is twitch1167
# Extracted author of post 55 is twitch1167
# Match? True
#
# Expected author of post 56 is nikkie1580
# Extracted author of post 56 is nikkie1580
# Match? True
#
# Expected author of post 57 is christinebryson
# Extracted author of post 57 is christinebryson
# Match? True
#
# Expected author of post 58 is christinebryson
# Extracted author of post 58 is christinebryson
# Match? True
#
# Expected author of post 59 is cmanthomas
# Extracted author of post 59 is cmanthomas
# Match? True
#
# Expected author of post 60 is KellyAC
# Extracted author of post 60 is KellyAC
# Match? True
#
# Expected author of post 61 is battlecat
# Extracted author of post 61 is battlecat
# Match? True
#
# Expected author of post 62 is greaseslapper
# Extracted author of post 62 is greaseslapper
# Match? True
#
# Expected author of post 63 is greaseslapper
# Extracted author of post 63 is greaseslapper
# Match? True
#
# Expected author of post 64 is greaseslapper
# Extracted author of post 64 is greaseslapper
# Match? True
#
# Expected author of post 65 is greaseslapper
# Extracted author of post 65 is greaseslapper
# Match? True
#
# Expected author of post 66 is BURR1978
# Extracted author of post 66 is BURR1978
# Match? True
#
# Expected author of post 67 is Silverlining15
# Extracted author of post 67 is Silverlining15
# Match? True
#
# Expected author of post 68 is case572
# Extracted author of post 68 is case572
# Match? True
#
# Expected author of post 69 is sniemi
# Extracted author of post 69 is sniemi
# Match? True
#
# Expected author of post 70 is ElizabethMC
# Extracted author of post 70 is ElizabethMC
# Match? True
#
# Expected author of post 71 is Kathy2956
# Extracted author of post 71 is Kathy2956
# Match? True
#
# Expected author of post 72 is Beentherehavehope
# Extracted author of post 72 is Beentherehavehope
# Match? True
#
# Expected author of post 73 is Guest101010
# Extracted author of post 73 is Guest101010
# Match? True
#
# Expected author of post 74 is Guest101010
# Extracted author of post 74 is Guest101010
# Match? True
#
# Expected author of post 75 is allie1013
# Extracted author of post 75 is allie1013
# Match? True
#
# Expected author of post 76 is Dmals41
# Extracted author of post 76 is Dmals41
# Match? True
#
# Expected author of post 77 is Day526
# Extracted author of post 77 is Day526
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Crohns-and-Aloe-vera/show/1364198
#
# Number of extracted conversation posts / usernames: 16
# Expected number of posts to be analyzed: 14
#
# Expected author of post 78 is surprisinglife
# Extracted author of post 78 is surprisinglife
# Match? True
#
# Expected author of post 79 is meniere135
# Extracted author of post 79 is S.  Kaul, MD
# Match? False
#
# Expected author of post 80 is bridget2007
# Extracted author of post 80 is meniere135
# Match? False
#
# Expected author of post 81 is surprisinglife
# Extracted author of post 81 is bridget2007
# Match? False
#
# Expected author of post 82 is surprisinglife
# Extracted author of post 82 is surprisinglife
# Match? True
#
# Expected author of post 83 is surprisinglife
# Extracted author of post 83 is surprisinglife
# Match? True
#
# Expected author of post 84 is Cheekecharlie
# Extracted author of post 84 is surprisinglife
# Match? False
#
# Expected author of post 85 is ulcerativecolitis
# Extracted author of post 85 is Cheekecharlie
# Match? False
#
# Expected author of post 86 is surprisinglife
# Extracted author of post 86 is ulcerativecolitis
# Match? False
#
# Expected author of post 87 is locoaloe
# Extracted author of post 87 is surprisinglife
# Match? False
#
# Expected author of post 88 is eastupper
# Extracted author of post 88 is locoaloe
# Match? False
#
# Expected author of post 89 is Abbyinokc
# Extracted author of post 89 is eastupper
# Match? False
#
# Expected author of post 90 is LoriSpurgeon
# Extracted author of post 90 is S.  Kaul, MD
# Match? False
#
# Expected author of post 91 is cynthiawan
# Extracted author of post 91 is Abbyinokc
# Match? False
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Why-do-my-feet-hurt-when-Im-about-to-have-a-bowel-movement/show/1439559
#
# Number of extracted conversation posts / usernames: 16
# Expected number of posts to be analyzed: 11
#
# Expected author of post 92 is PinkPlaydoh
# Extracted author of post 92 is PinkPlaydoh
# Match? True
#
# Expected author of post 93 is krisaflor
# Extracted author of post 93 is S.  Kaul, MD
# Match? False
#
# Expected author of post 94 is bad20
# Extracted author of post 94 is krisaflor
# Match? False
#
# Expected author of post 95 is allmymarbles
# Extracted author of post 95 is bad20
# Match? False
#
# Expected author of post 96 is allmymarbles
# Extracted author of post 96 is allmymarbles
# Match? True
#
# Expected author of post 97 is utilaman
# Extracted author of post 97 is allmymarbles
# Match? False
#
# Expected author of post 98 is utilaman
# Extracted author of post 98 is utilaman
# Match? True
#
# Expected author of post 99 is Karma34690
# Extracted author of post 99 is utilaman
# Match? False
#
# Expected author of post 100 is utilaman
# Extracted author of post 100 is Karma34690
# Match? False
#
# Expected author of post 101 is Cooltea
# Extracted author of post 101 is utilaman
# Match? False
#
# Expected author of post 102 is Burchsc
# Extracted author of post 102 is S.  Kaul, MD
# Match? False
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Crohns-Disease--vomiting/show/512883
#
# Number of extracted conversation posts / usernames: 24
# Expected number of posts to be analyzed: 24
#
# Expected author of post 103 is Lalasoto
# Extracted author of post 103 is Lalasoto
# Match? True
#
# Expected author of post 104 is lizziecee
# Extracted author of post 104 is lizziecee
# Match? True
#
# Expected author of post 105 is Lalasoto
# Extracted author of post 105 is Lalasoto
# Match? True
#
# Expected author of post 106 is lizziecee
# Extracted author of post 106 is lizziecee
# Match? True
#
# Expected author of post 107 is lizziecee
# Extracted author of post 107 is lizziecee
# Match? True
#
# Expected author of post 108 is Lalasoto
# Extracted author of post 108 is Lalasoto
# Match? True
#
# Expected author of post 109 is lizziecee
# Extracted author of post 109 is lizziecee
# Match? True
#
# Expected author of post 110 is Lalasoto
# Extracted author of post 110 is Lalasoto
# Match? True
#
# Expected author of post 111 is VCASILLAS
# Extracted author of post 111 is VCASILLAS
# Match? True
#
# Expected author of post 112 is Lalasoto
# Extracted author of post 112 is Lalasoto
# Match? True
#
# Expected author of post 113 is Shoshchana
# Extracted author of post 113 is Shoshchana
# Match? True
#
# Expected author of post 114 is reneeloveskindergarten
# Extracted author of post 114 is reneeloveskindergarten
# Match? True
#
# Expected author of post 115 is Leslie406
# Extracted author of post 115 is Leslie406
# Match? True
#
# Expected author of post 116 is WesleyDale
# Extracted author of post 116 is WesleyDale
# Match? True
#
# Expected author of post 117 is AEOtero
# Extracted author of post 117 is AEOtero
# Match? True
#
# Expected author of post 118 is travisdh
# Extracted author of post 118 is travisdh
# Match? True
#
# Expected author of post 119 is pro2675
# Extracted author of post 119 is pro2675
# Match? True
#
# Expected author of post 120 is Primus75
# Extracted author of post 120 is Primus75
# Match? True
#
# Expected author of post 121 is Heide4277
# Extracted author of post 121 is Heide4277
# Match? True
#
# Expected author of post 122 is jade111
# Extracted author of post 122 is jade111
# Match? True
#
# Expected author of post 123 is Queen4hart
# Extracted author of post 123 is Queen4hart
# Match? True
#
# Expected author of post 124 is Queen4hart
# Extracted author of post 124 is Queen4hart
# Match? True
#
# Expected author of post 125 is alymea
# Extracted author of post 125 is alymea
# Match? True
#
# Expected author of post 126 is Missincolorado
# Extracted author of post 126 is Missincolorado
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Chronic-Pouchitis/show/674166
# Number of extracted conversation posts / usernames: 16
# Expected number of posts to be analyzed: 16
#
# Expected author of post 127 is azure77
# Extracted author of post 127 is azure77
# Match? True
#
# Expected author of post 128 is TrudieC
# Extracted author of post 128 is TrudieC
# Match? True
#
# Expected author of post 129 is azure77
# Extracted author of post 129 is azure77
# Match? True
#
# Expected author of post 130 is TrudieC
# Extracted author of post 130 is TrudieC
# Match? True
#
# Expected author of post 131 is cka58
# Extracted author of post 131 is cka58
# Match? True
#
# Expected author of post 132 is niki26
# Extracted author of post 132 is niki26
# Match? True
#
# Expected author of post 133 is kr00110
# Extracted author of post 133 is kr00110
# Match? True
#
# Expected author of post 134 is TrudieC
# Extracted author of post 134 is TrudieC
# Match? True
#
# Expected author of post 135 is lightman16
# Extracted author of post 135 is lightman16
# Match? True
#
# Expected author of post 136 is jb1000
# Extracted author of post 136 is jb1000
# Match? True
#
# Expected author of post 137 is Sunflowerserina
# Extracted author of post 137 is Sunflowerserina
# Match? True
#
# Expected author of post 138 is Justme45732
# Extracted author of post 138 is Justme45732
# Match? True
#
# Expected author of post 139 is bren1703
# Extracted author of post 139 is bren1703
# Match? True
#
# Expected author of post 140 is Fulton762
# Extracted author of post 140 is Fulton762
# Match? True
#
# Expected author of post 141 is dbg30
# Extracted author of post 141 is dbg30
# Match? True
#
# Expected author of post 142 is lioness40
# Extracted author of post 142 is lioness40
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/My-joints-are-killing-me/show/425447
#
# Number of extracted conversation posts / usernames: 29
# Expected number of posts to be analyzed: 29
#
# Expected author of post 143 is holyleo
# Extracted author of post 143 is holyleo
# Match? True
#
# Expected author of post 144 is UncontrolledSarcasm
# Extracted author of post 144 is UncontrolledSarcasm
# Match? True
#
# Expected author of post 145 is katta
# Extracted author of post 145 is katta
# Match? True
#
# Expected author of post 146 is ladybea
# Extracted author of post 146 is ladybea
# Match? True
#
# Expected author of post 147 is elroque
# Extracted author of post 147 is elroque
# Match? True
#
# Expected author of post 148 is nace1
# Extracted author of post 148 is nace1
# Match? True
#
# Expected author of post 149 is tmoruri
# Extracted author of post 149 is tmoruri
# Match? True
#
# Expected author of post 150 is mimi134
# Extracted author of post 150 is mimi134
# Match? True
#
# Expected author of post 151 is dmr1954
# Extracted author of post 151 is dmr1954
# Match? True
#
# Expected author of post 152 is amycummings
# Extracted author of post 152 is amycummings
# Match? True
#
# Expected author of post 153 is babsygal
# Extracted author of post 153 is babsygal
# Match? True
#
# Expected author of post 154 is Coleigh
# Extracted author of post 154 is Coleigh
# Match? True
#
# Expected author of post 155 is Nonnie59
# Extracted author of post 155 is Nonnie59
# Match? True
#
# Expected author of post 156 is Lucky0317
# Extracted author of post 156 is Lucky0317
# Match? True
#
# Expected author of post 157 is dianne775
# Extracted author of post 157 is dianne775
# Match? True
#
# Expected author of post 158 is nace1
# Extracted author of post 158 is nace1
# Match? True
#
# Expected author of post 159 is trina99
# Extracted author of post 159 is trina99
# Match? True
#
# Expected author of post 160 is MissDana
# Extracted author of post 160 is MissDana
# Match? True
#
# Expected author of post 161 is kerry180
# Extracted author of post 161 is kerry180
# Match? True
#
# Expected author of post 162 is Nitemare1
# Extracted author of post 162 is Nitemare1
# Match? True
#
# Expected author of post 163 is Nitemare1
# Extracted author of post 163 is Nitemare1
# Match? True
#
# Expected author of post 164 is Portia0812
# Extracted author of post 164 is Portia0812
# Match? True
#
# Expected author of post 165 is flyingv8
# Extracted author of post 165 is flyingv8
# Match? True
#
# Expected author of post 166 is rogergruv
# Extracted author of post 166 is rogergruv
# Match? True
#
# Expected author of post 167 is CAFERDIG
# Extracted author of post 167 is CAFERDIG
# Match? True
#
# Expected author of post 168 is Mtbing
# Extracted author of post 168 is Mtbing
# Match? True
#
# Expected author of post 169 is Mtbing
# Extracted author of post 169 is Mtbing
# Match? True
#
# Expected author of post 170 is Mtbing
# Extracted author of post 170 is Mtbing
# Match? True
#
# Expected author of post 171 is Mtbing
# Extracted author of post 171 is Mtbing
# Match? True
#
# Conversation URL: http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Ulcerative-Colitis-and-Hair-Loss-in-Women/show/8690
#
# Number of extracted conversation posts / usernames: 20
# Expected number of posts to be analyzed: 19
#
# Expected author of post 172 is Azzub
# Extracted author of post 172 is Azzub
# Match? True
#
# Expected author of post 173 is Shebah
# Extracted author of post 173 is Shebah
# Match? True
#
# Expected author of post 174 is Tworm
# Extracted author of post 174 is Tworm
# Match? True
#
# Expected author of post 175 is Mint67
# Extracted author of post 175 is Mint67
# Match? True
#
# Expected author of post 176 is MsLA2003
# Extracted author of post 176 is MsLA2003
# Match? True
#
# Expected author of post 177 is sirithturwen
# Extracted author of post 177 is sirithturwen
# Match? True
#
# Expected author of post 178 is VANESSA09
# Extracted author of post 178 is VANESSA09
# Match? True
#
# Expected author of post 179 is batman858
# Extracted author of post 179 is batman858
# Match? True
#
# Expected author of post 180 is joyeta
# Extracted author of post 180 is joyeta
# Match? True
#
# Expected author of post 181 is sasha209
# Extracted author of post 181 is sasha209
# Match? True
#
# Expected author of post 182 is thisisme149
# Extracted author of post 182 is thisisme149
# Match? True
#
# Expected author of post 183 is fricklefrack
# Extracted author of post 183 is fricklefrack
# Match? True
#
# Expected author of post 184 is bethfrdh1
# Extracted author of post 184 is bethfrdh1
# Match? True
#
# Expected author of post 185 is Caryopteris
# Extracted author of post 185 is Caryopteris
# Match? True
#
# Expected author of post 186 is deisel2750
# Extracted author of post 186 is deisel2750
# Match? True
#
# Expected author of post 187 is deisel2750
# Extracted author of post 187 is deisel2750
# Match? True
#
# Expected author of post 188 is deisel2750
# Extracted author of post 188 is deisel2750
# Match? True
#
# Expected author of post 189 is deisel2750
# Extracted author of post 189 is deisel2750
# Match? True
#
# Expected author of post 190 is mickeymouse600
# Extracted author of post 190 is mickeymouse600
# Match? True
#
# Disease ID: HIF2016_DIS02
#
# Conversation URL: http://www.medhelp.org/posts/Breast-Cancer/solid-cystic-complex-cyst-at-6-o-clock-position/show/2782062
#
# Number of extracted conversation posts / usernames: 12
# Expected number of posts to be analyzed: 14
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 driver()
#
# Cell In[7], line 6, in driver()
#       4 for disease in diseases["disease_id"]:
#       5     print("Disease ID: {}\n".format(disease))
# ----> 6     posts_dataframe = scrape_conversation_posts(disease)
#
# Cell In[6], line 13, in scrape_conversation_posts(disease)
#      10     print("Number of extracted conversation posts / usernames: {}".format(len(conversation_posts)))
#      11     print("Expected number of posts to be analyzed: {}\n".format(
#      12         expected_posts_per_conversation[row["conversation_id"]]))
# ---> 13     assert(len(conversation_posts) >= expected_posts_per_conversation[row["conversation_id"]])
#      15     add_posts(conversation_posts, usernames, posts_dataframe, row["conversation_id"])
#      17 return posts_dataframe
#
# AssertionError:

# %% [markdown]
# TESTING BLOCKS

# %%
# TESTING SENTENCE EXTRACTION.

post = "That does sound like you have a food sensitivity to coffee.  I don't think it's the caffeine, but one way you can figure out if it's caffeine is to try black or green tea (both are from the same plant).  Just be mindful that the green tea can still carry a problem with lead from the processing.  Dr. Mercola has articles that explain this more thoroughly.  There are some that he explains don't have this risk.  I know it seems like there shouldn't be a risk, since they are steaming, then drying to keep the leaves green.  So, I'm not sure where the lead comes from.  But, black tea doesn't carry the same risk.  I myself simply can't drink tea, though, because the tannin bothers me."
post_id = "HIF2016_DIS00_CONV00_POST002"
disease = "HIF2016_DIS00"

sentence_dataframe = pd.read_csv("gold_standard/sentences/" + disease + ".tsv", delimiter = "\t")

print(post)
print("\n\n---------\n\n")

for sentence_number, sentence in sentence_dataframe.iterrows():
    if sentence["post_id"] == post_id:
        print("Start index: {}, end index: {}".format(sentence["start_index"], sentence["end_index"]))
        print("Mined sentence (number: {}): {}\n".format(sentence_number, post[sentence["start_index"] - 1 :
                                                                               sentence["end_index"] - 1].strip()))

# %%
# TESTING URL MINING.

# posts to take a look at:
conversation_url = "http://www.medhelp.org/posts/Allergies---Food/Tremors-when-touching-certain-foods/show/1537785" # (ERROR IN SPACING)
# conversation_url = "http://www.medhelp.org/posts/Allergies---Food/36-and-just-had-my-first-reaction-to-shrimp/show/1542663" (ERROR IN SPACING)
# conversation_url = "http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Crohns-and-Aloe-vera/show/1364198" (COMPLETE ERROR IN PARSING)
# conversation_url = "http://www.medhelp.org/posts/Crohns-Disease---Ulcerative-Colitis/Why-do-my-feet-hurt-when-Im-about-to-have-a-bowel-movement/show/1439559" (COMPLETE ERROR IN PARSING)


posts, usernames = scrape_url(conversation_url)

print("Length of posts: {}".format(len(posts)))
print("Length of usernames: {}".format(len(usernames)))

print(posts)
print(usernames)
# Out:
# Conversation URL: http://www.medhelp.org/posts/Allergies---Food/Tremors-when-touching-certain-foods/show/1537785
#
# Length of posts: 13
# Length of usernames: 13
# ['I am a female (31) and was diagnosed with severe adrenal exhaustion and hypothyroidism about 1 1/2 yrs. ago. I was on oxygen for 4 mos. just prior to being diagnosed. I was also on physiological doses of hydrocortisone and florinef for about 9mo. I have been slowly improving but for almost 1 yr. now, if I touch certain foods, supplements, drinks or medications, my body starts to tremor. This will go away by removing my hands from that product. However, I have had some severe reactions (neck jerks, rash, lightheadedness, difficulty breathing, etc.) by ingesting food or a supplement that my body did not initially react to. If touching after a reaction, I will get severe tremors. The list of items is ever increasing making it hard to find food to eat. One certain manufacturer of precription drugs works all the time, but others of the exact same prescription create tremors and severe reactions.\n\nI have researched the internet countless hours and have not found any doctor, medical professional or nutrionist who have ever heard of this. I believe solving this problem is key to restoring my health.\n\nAny help or direction would be greatly appreciated.', 'Hi,\n\nFrom your long history it seems that due to long suffering of the disease you have got Anxiety neurosis causing all problems.\nIn hypothyroid this type of symptoms is common so see that your thyroid is under control.\nGo for routine check up for thyroid and adjust the dose of medicine accordingly.\nOnce thyroid is all right your most of the symptoms will go.\nIf you have still problem you consult psychiatrist for anxiety neurosis.\n\nWish you speedy recovery.', 'Thanks so much for your comments. My daughter has already seen a prominent neuropsychologist who did very extensive testing and ruled out psychological reasons. She has not been able to handle thyroid as the adrenals are too still too weak. If she takes thyroid meds., then she has heart palpitations. Just touching it brings on hand and arm tremors.\n\nAny other suggestions would be greatly appreciated.', 'Hello,\n\nUnderstand your predicament. However, the diagnosis of allergy is difficult to prove or refute. Clinical suspicion and trial of elimination diets are used. An allergy specialist might be able to help you. You can start by maintaining a food dairy and record those specific items that are inducing your symptoms. This will help to narrow down the search. He may identify the allergen by skin testing and help to desensitize you. \n\nHope This Helped and Do Keep Us Posted!!', 'Thank you for your advice and I appreciate your interest in helping to identify this mystery. About 1 year ago, my daughter\'s NMD administered a blood test for food allergy (FoodStats Antibody Assessment) by US BioTek using "Standard Food Panel IgG". The test results indicated a number of sensitivities and those foods have been avoided since then. There are a few that are rotational and those are closely monitored using a calendar. She has a growing number of sensitivities since this test and her doctor asked her to do an experiment at our local health food store where we purchase many of our produce. As an example, there is one type of apple that was grown by the same company but in a different location. She could touch one and not have any tremors but when touching the other, she experienced tremors. This remained consistent even 1 week later. This also happens on other produce.\n\nLastly, she was in the hospital for pneumonia in April 2011. The doctor ordered IV antibiotics to be administered. There were two different antibiotic IV bags to be given, but when she touched one bag, she had violent muscle spasms over the whole body which tripped the heart monitor and read greater than 140 bpm. The nurses had never seen this and didn\'t know what to do until we instructed them to take the bag away quickly. The tremors or muscle spasms subsided, heart rate went back to normal, and muscle spasms stopped. The other antibiotic bag did not pr ...
# ['Jayhawk29', 'Ashwin  Bhandari, MBBS', 'Jayhawk29', 'Paderla  Anitha, DNB ', 'Jayhawk29', 'seattlemom2plus', 'Jayhawk29', 'ChitChatNine', 'seattlemom2plus', 'Jayhawk29', 'seattlemom2plus', 'wilsongarrett', 'ChitChatNine']
